# %%
from VVQVAE import VVQVAE
import torch

# %%
t = torch.zeros((1, 1, 256, 192, 192)).cuda()

# %%
model = VVQVAE().cuda()

# %%
model(t)
# Out:
# (tensor([[[[[0.2031, 0.3798, 0.1930,  ..., 0.3820, 0.1869, 0.4312],
#             [0.3871, 0.4204, 0.4162,  ..., 0.4168, 0.4195, 0.4205],
#             [0.1930, 0.4191, 0.2162,  ..., 0.4191, 0.2122, 0.4371],
#             ...,
#             [0.3826, 0.4172, 0.4186,  ..., 0.4156, 0.4190, 0.4206],
#             [0.1906, 0.4195, 0.2189,  ..., 0.4190, 0.2220, 0.4415],
#             [0.4419, 0.4446, 0.4449,  ..., 0.4432, 0.4458, 0.4284]],
#
#            [[0.3918, 0.4234, 0.4173,  ..., 0.4205, 0.4156, 0.4425],
#             [0.4080, 0.4272, 0.4819,  ..., 0.4261, 0.4818, 0.4331],
#             [0.3859, 0.4833, 0.4707,  ..., 0.4814, 0.4678, 0.4794],
#             ...,
#             [0.4095, 0.4273, 0.4809,  ..., 0.4247, 0.4796, 0.4325],
#             [0.3821, 0.4818, 0.4676,  ..., 0.4808, 0.4733, 0.4856],
#             [0.4512, 0.4587, 0.4769,  ..., 0.4572, 0.4792, 0.4616]],
#
#            [[0.2079, 0.4276, 0.2206,  ..., 0.4256, 0.2119, 0.4573],
# ...
